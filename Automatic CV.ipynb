# %%
#pip install cvlib

# %%
import cv2
import matplotlib.pyplot as plt
from cvlib.object_detection import draw_bbox
import cvlib

# %%
img=cv2.imread("cars.jpg")

# %%
plt.imshow(img);

# %%
box, label, count = cvlib.detect_common_objects(img)

# %%
output = draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
len(label)
# Out:
# 12

# %%
t=0
for i in label:
    if i == "car":
        t=t+1
print(str(t)+" adet araba var")
# Out:
# 11 adet araba var

# %%
img2=cv2.imread("g8.jpg")

# %%
plt.imshow(img2)

# %%
box, label, count = cvlib.detect_common_objects(img2)
output = draw_bbox(img2,box,label,count)

# %%
label
# Out:
# ['person', 'person', 'person', 'person', 'person', 'person', 'tie']

# %%
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
t=0
for i in label:
    if i == "person":
        t=t+1
print(str(t)+" adet insan var")
# Out:
# 6 adet insan var

# %%
img3=cv2.imread("kitchen.jpg")

# %%
plt.imshow(img3)

# %%
box, label, count = cvlib.detect_common_objects(img3)
output = draw_bbox(img3,box,label,count)

# %%
label
# Out:
# ['chair',
#  'chair',
#  'chair',
#  'dining table',
#  'bowl',
#  'potted plant',
#  'apple',
#  'apple',
#  'bottle',
#  'vase',
#  'apple']

# %%
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
t=0
for i in label:
    if i == "chair":
        t=t+1
print(str(t)+" adet chair var")
# Out:
# 3 adet chair var

# %%
count
# Out:
# [0.9956292510032654,
#  0.98787522315979,
#  0.9683630466461182,
#  0.8659927248954773,
#  0.7289490103721619,
#  0.6028242707252502,
#  0.5903155207633972,
#  0.579734206199646,
#  0.5583931803703308,
#  0.5393682718276978,
#  0.520172655582428]

# %%
img4=cv2.imread("dogs.jpg")

# %%
plt.imshow(img4)

# %%
box, label, count = cvlib.detect_common_objects(img4)
output = draw_bbox(img4,box,label,count)

# %%
label
# Out:
# ['dog', 'dog', 'dog', 'dog']

# %%
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
t=0
for i in label:
    if i == "dog":
        t=t+1
print(str(t)+" adet köpek var")
# Out:
# 4 adet köpek var
